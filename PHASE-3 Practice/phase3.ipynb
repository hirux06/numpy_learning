# %% [markdown]
# ## Advance operation with Buisness examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data strucure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000], # Paradise Biryani
    [2, 120000, 140000, 160000, 190000], # Beijing Bites
    [3, 200000, 230000, 260000, 300000], # Pizza Hub
    [4, 180000, 210000, 240000, 270000], # Burger Point
    [5, 160000, 185000, 205000, 230000]  # Chai Point
])

print(" === Zomato sales analyses === ")
print("\n Sales data shape: ", sales_data.shape)
print("\n Sample data for first 3 restaurents: ", sales_data[:3])
# Out:
#  === Zomato sales analyses ===
#
#  Sales data shape:  (5, 5)
#
#  Sample data for first 3 restaurents:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# Total sales per year
print(np.sum(sales_data, axis=0))

yearly_total = np.sum(sales_data[:, 1:], axis=1)
print(yearly_total)

# Minimum sales per restaurent
min_sales = np.min(sales_data[:, 1:], axis=1)
print(min_sales)

#Maximum sales per year
max_sales = np.max(sales_data[:,1:], axis=0)
print(max_sales)

# Average sales per restaurent
avg_sales = np.average(sales_data[:,1:], axis=1)
print(avg_sales)
# Out:
# [     15  810000  945000 1085000 1240000]
# [800000 610000 990000 900000 780000]
# [150000 120000 200000 180000 160000]
# [200000 230000 260000 300000]
# [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(cumsum)

plt.figure(figsize=(10, 6))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumulative sales across all restaurent.")
plt.xlabel("Years")
plt.ylabel("sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

print("Vector addition: ", vector1 + vector2)
print("\nVector multiplication: ", vector1*vector2)
print("\nDot product: ", np.dot(vector1, vector2))

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1*np.linalg.norm(vector2))))
print(angle)
# Out:
# Vector addition:  [ 7  9 11 13 15]
#
# Vector multiplication:  [ 6 14 24 36 50]
#
# Dot product:  130
# 0.26554161733900966

# %%
restaurent_types = np.array(["biryani", "chineese", "pizza", "burger", "cafe"])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper: ", vectorized_upper(restaurent_types))
# Out:
# Vectorized Upper:  ['BIRYANI' 'CHINEESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:, 1:]
print(monthly_avg)
